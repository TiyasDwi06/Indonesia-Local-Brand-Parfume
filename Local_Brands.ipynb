# %% [markdown]
# # import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# read csv files
parfume = pd.read_csv('C:/Users/LENOVO/Documents/Data Science/Data Percobaan 2/Indonesian Local Perfume Brands/Indonesian Local Perfume Brands.csv')

# %%
parfume.head()
# Out:
#            brand                                  instagram_link  followers  \
# 0      Alchemist  https://www.instagram.com/alchemist.fragrance/      17800
# 1  Alien Objects         https://www.instagram.com/alienobjects/      15700
# 2  ALT Perfumery        https://www.instagram.com/alt.perfumery/       6528
# 3      Ara Scent            https://www.instagram.com/ara.scent/        119
# 4         Aromes            https://www.instagram.com/aromes.id/      15700
#
#    year          variant                                       variant_link  \
# 0  2022      Powder Room  https://shopee.co.id/alchemist.fragrance/17137...
# 1  2019             XOXO      https://shopee.co.id/alienobjects/14283008217
# 2  2021  Moroccan Sunset      https://shopee.co.id/altperfumery/12639590547
# 3  2023            Sogno         https://shopee.co.id/ara.scent/22247002537
# 4  2022       Crazy Sexy         https://shopee.co.id/aromes.id/19521086160
#
# ...

# %%
# view missing data
parfume.isnull().sum()
# Out:
# brand               0
# instagram_link      0
# followers           0
# year                0
# variant             0
# variant_link        0
# concentration       0
# size                0
# price               0
# price_per_ml        0
# top_notes1          0
# top_notes2          7
# top_notes3         38
# top_notes4         85
# top_notes5        102
# top_notes6        108
# mid_notes1          9
# mid_notes2         19
# mid_notes3         48
# mid_notes4         90
# mid_notes5        104
# mid_notes6        111
# mid_notes7        112
# Unnamed: 23       114
# Unnamed: 24       114
# base_notes1        14
# base_notes2        20
# base_notes3        46
# base_notes4        82
# base_notes5       101
# base_notes6       106
# Unnamed: 31       114
# Unnamed: 32       114
# Unnamed: 33       114
# base_notes7       111
# dtype: int64

# %%
# view columns
parfume.columns
# Out:
# Index(['brand', 'instagram_link', 'followers', 'year', 'variant',
#        'variant_link', 'concentration', 'size', 'price', 'price_per_ml',
#        'top_notes1', 'top_notes2', 'top_notes3', 'top_notes4', 'top_notes5',
#        'top_notes6', 'mid_notes1', 'mid_notes2', 'mid_notes3', 'mid_notes4',
#        'mid_notes5', 'mid_notes6', 'mid_notes7', 'Unnamed: 23', 'Unnamed: 24',
#        'base_notes1', 'base_notes2', 'base_notes3', 'base_notes4',
#        'base_notes5', 'base_notes6', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'base_notes7'],
#       dtype='object')

# %%
# delete unused columns
parfume.drop(columns=['base_notes3', 'base_notes4',
       'base_notes5', 'base_notes6', 'Unnamed: 31', 'Unnamed: 32',
       'Unnamed: 33', 'base_notes7','mid_notes3', 'mid_notes4',
       'mid_notes5', 'mid_notes6', 'mid_notes7', 'Unnamed: 23', 'Unnamed: 24', 'top_notes3', 'top_notes4', 'top_notes5',
       'top_notes6'], inplace=True)

# %%
parfume.head()
# Out:
#            brand                                  instagram_link  followers  \
# 0      Alchemist  https://www.instagram.com/alchemist.fragrance/      17800
# 1  Alien Objects         https://www.instagram.com/alienobjects/      15700
# 2  ALT Perfumery        https://www.instagram.com/alt.perfumery/       6528
# 3      Ara Scent            https://www.instagram.com/ara.scent/        119
# 4         Aromes            https://www.instagram.com/aromes.id/      15700
#
#    year          variant                                       variant_link  \
# 0  2022      Powder Room  https://shopee.co.id/alchemist.fragrance/17137...
# 1  2019             XOXO      https://shopee.co.id/alienobjects/14283008217
# 2  2021  Moroccan Sunset      https://shopee.co.id/altperfumery/12639590547
# 3  2023            Sogno         https://shopee.co.id/ara.scent/22247002537
# 4  2022       Crazy Sexy         https://shopee.co.id/aromes.id/19521086160
#
# ...

# %%
# change the column name
parfume.rename(columns={'top_notes1':'top_1', 'top_notes2':'top_2','mid_notes1':'mid_1','mid_notes2':'mid_2','base_notes1':'base_1','base_notes2':'base_2'}, inplace=True)

# %%
# Fill in empty data in several columns that contain missing values
parfume['top_2'].mode()
# Out:
# 0    Bergamot
# Name: top_2, dtype: object

# %%
parfume['top_2'].fillna('Bergamot', inplace=True)

# %%
parfume['mid_1'].mode()
# Out:
# 0    Jasmine
# 1       Rose
# Name: mid_1, dtype: object

# %%
parfume['mid_1'].fillna('Jasmine', inplace=True)

# %%
parfume['mid_2'].mode()
# Out:
# 0    Rose
# Name: mid_2, dtype: object

# %%
parfume['mid_2'].fillna('Rose', inplace=True)

# %%
parfume['base_1'].mode()
# Out:
# 0    Vanilla
# Name: base_1, dtype: object

# %%
parfume['base_1'].fillna('Vanilla', inplace=True)

# %%
parfume['base_2'].mode()
# Out:
# 0    Amber
# Name: base_2, dtype: object

# %%
parfume['base_2'].fillna('Amber', inplace=True)

# %%
parfume.isnull().sum()
# Out:
# brand             0
# instagram_link    0
# followers         0
# year              0
# variant           0
# variant_link      0
# concentration     0
# size              0
# price             0
# price_per_ml      0
# top_1             0
# top_2             0
# mid_1             0
# mid_2             0
# base_1            0
# base_2            0
# dtype: int64

# %%
# perform data separation using split
variant = parfume['variant_link'].str.split('/', expand=True)

# %%
variant.head()
# Out:
#         0 1             2                    3            4     5
# 0  https:    shopee.co.id  alchemist.fragrance  17137354148  None
# 1  https:    shopee.co.id         alienobjects  14283008217  None
# 2  https:    shopee.co.id         altperfumery  12639590547  None
# 3  https:    shopee.co.id            ara.scent  22247002537  None
# 4  https:    shopee.co.id            aromes.id  19521086160  None

# %%
variant.rename(columns={2 : 'e_commerce'}, inplace=True)

# %%
parfume['e_commerce'] = variant['e_commerce']

# %%
#change the data in the e-commerce column
parfume['e_commerce'] = parfume['e_commerce'].str.replace('.co.id','', regex=True)
parfume['e_commerce'] = parfume['e_commerce'].str.replace('.link','', regex=True)
parfume['e_commerce'] = parfume['e_commerce'].str.replace('.sirclo.me','', regex=True)
parfume['e_commerce'] = parfume['e_commerce'].str.replace('www.','', regex=True)
parfume['e_commerce'] = parfume['e_commerce'].str.replace('.com','', regex=True)

# %%
parfume['e_commerce'] = parfume['e_commerce'].str.replace('azwaryperfume','tokopedia', regex=True)

# %%
parfume['e_commerce'].value_counts()
# Out:
# e_commerce
# shopee       106
# tokopedia      9
# Name: count, dtype: int64

# %%
parfume.drop(columns=['variant_link','instagram_link'], inplace=True)

# %%
parfume.head()
# Out:
#            brand  followers  year          variant concentration  size  \
# 0      Alchemist      17800  2022      Powder Room           EDP    50
# 1  Alien Objects      15700  2019             XOXO           EDP    50
# 2  ALT Perfumery       6528  2021  Moroccan Sunset           EDP    50
# 3      Ara Scent        119  2023            Sogno           EDP    30
# 4         Aromes      15700  2022       Crazy Sexy           EDP    50
#
#         price price_per_ml                top_1       top_2           mid_1  \
# 0  199,000.00     3,980.00  Fresh Watery Accord        Rose          Violet
# 1  750,000.00    15,000.00                  Dew  Strawberry  Orange Blossom
# 2  229,000.00     4,580.00               Neroli    Bergamot  Orange Blossom
# 3  139,000.00     4,633.33                Apple    Bergamot            Rose
# 4  299,000.00     5,980.00            Raspberry  Lemon Peel          Almond
#
#             mid_2   base_1     base_2 e_commerce
# ...

# %%
parfume['price'] = parfume['price'].str.replace(',','')
parfume['price'] = parfume['price'].str.replace('.00','')
parfume['price'] = parfume['price'].astype('int')

# %%
# Change the data in the price_per_ml column to make calculations easier
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace(',','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.00','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.33','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.27','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.50','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.67','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.57','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.86','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.99','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.64','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.05','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.43','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.71','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.88','')
parfume['price_per_ml'] = parfume['price_per_ml'].str.replace('.48','')
parfume['price_per_ml'] = parfume['price_per_ml'].astype('int')

# %%
parfume.head()
# Out:
#            brand  followers  year          variant concentration  size  \
# 0      Alchemist      17800  2022      Powder Room           EDP    50
# 1  Alien Objects      15700  2019             XOXO           EDP    50
# 2  ALT Perfumery       6528  2021  Moroccan Sunset           EDP    50
# 3      Ara Scent        119  2023            Sogno           EDP    30
# 4         Aromes      15700  2022       Crazy Sexy           EDP    50
#
#     price  price_per_ml                top_1       top_2           mid_1  \
# 0  199000          3980  Fresh Watery Accord        Rose          Violet
# 1  750000         15000                  Dew  Strawberry  Orange Blossom
# 2  229000          4580               Neroli    Bergamot  Orange Blossom
# 3  139000          4633                Apple    Bergamot            Rose
# 4  299000          5980            Raspberry  Lemon Peel          Almond
#
#             mid_2   base_1     base_2 e_commerce
# 0  Orange Blossom     Musk     Marine     shopee
# ...

# %% [markdown]
# # Visualisasi

# %%
Visualisasi_commerce = parfume['e_commerce'].value_counts().reset_index(name='Counts')
Visualisasi_commerce_plot = sns.barplot(data=Visualisasi_commerce, x='e_commerce', y='Counts')
Visualisasi_commerce_plot.set_xlabel('e-commerce', fontweight='bold')
Visualisasi_commerce_plot.set_ylabel('Counts', fontweight='bold')
Visualisasi_commerce_plot.set_title('Visualisasi e-Commerce', size = 'xx-large', fontweight='heavy')
Visualisasi_commerce_plot.bar_label(Visualisasi_commerce_plot.containers[0])
plt.show()

# %%
sns.barplot(data= parfume, x='year', y='price') 
plt.title('Harga tertinggi berdasarkan botol', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
sns.barplot(data=parfume, x='year', y='size')
plt.title('Size paling laku', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('size per ML') 
plt.xticks
plt.show()

# %%
Visualisasi_concentration = parfume['concentration'].value_counts().reset_index(name='Counts')
Visualisasi_concentration_plot = sns.barplot(data=Visualisasi_concentration, x='concentration', y='Counts')
Visualisasi_concentration_plot.set_xlabel('concentration', fontweight='bold')
Visualisasi_concentration_plot.set_ylabel('Counts', fontweight='bold')
Visualisasi_concentration_plot.set_title('Visualisasi concentration', size = 'xx-large', fontweight='heavy')
Visualisasi_concentration_plot.bar_label(Visualisasi_concentration_plot.containers[0])
plt.show()

# %%
parfume['base_1'].value_counts()
# Out:
# base_1
# Vanilla                33
# Musk                   17
# Amber                   6
# Sandalwood              5
# White Musk              4
# Patchouli               4
# Tonka Bean              3
# Ambergris               3
# Benzoin                 2
# Amberwood               2
# Agarwood                2
# Suede                   2
# Iris                    2
# Oud                     2
# Sandalwood              2
# Cedarwood               2
# Clove                   1
# Patchouli Indonesia     1
# Oakmoss                 1
# Grean Tea               1
# Praline                 1
# Amber Musk              1
# Cashmere                1
# Papyrus                 1
# Synthetic Musk          1
# Wood                    1
# Almond                  1
# Pear                    1
# Citrus                  1
# Vetiver                 1
# Ambroxan                1
# Leather                 1
# Lavender                1
# Resin                   1
# Dried Fruits            1
# ...

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data top 1', fontweight='bold', size='xx-large') 
sns.countplot(data=parfume, x='top_1')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data top 2', fontweight='bold', size='xx-large')
sns.countplot(data=parfume, x='top_2')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data mid_1', fontweight='bold', size='xx-large')
sns.countplot(data=parfume, x='mid_1')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data mid_2', fontweight='bold', size='xx-large')
sns.countplot(data=parfume, x='mid_2')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data base_1', fontweight='bold', size='xx-large')
sns.countplot(data=parfume, x='base_1')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle('Visualisasi data base_2', fontweight='bold', size='xx-large')
sns.countplot(data=parfume, x='base_2')
plt.xlabel('Tingkat')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %%
parfume.head(2)
# Out:
#            brand  followers  year      variant concentration  size   price  \
# 0      Alchemist      17800  2022  Powder Room           EDP    50  199000
# 1  Alien Objects      15700  2019         XOXO           EDP    50  750000
#
#    price_per_ml                top_1       top_2           mid_1  \
# 0          3980  Fresh Watery Accord        Rose          Violet
# 1         15000                  Dew  Strawberry  Orange Blossom
#
#             mid_2   base_1  base_2 e_commerce
# 0  Orange Blossom     Musk  Marine     shopee
# 1            Rose  Vanilla   Amber     shopee

# %%
Follower_brands = parfume.groupby('brand')['followers'].max().reset_index().sort_values('followers', ascending=False)

# %%
Follower_brands.head()
# Out:
#                   brand  followers
# 21           De.Claires     541000
# 58  Mother of Perfumery     316000
# 36                 HMNS     306000
# 60              Mykonos     286000
# 90      Santigi Perfume     167000

# %%
parfume.to_excel('Indonesia_LocalBrands.xlsx')
